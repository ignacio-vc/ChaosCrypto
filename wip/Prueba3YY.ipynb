# %%
include("/Users/Yuriko/ChaosCrypto.jl/src/Sin3.jl")
# Out:
# Interact.Slider{Float64}(Signal{Float64}(0.040100000000000004, nactions=0),"φ",0.040100000000000004,0.0001:0.01:0.0901,true)
# φ = 0.040100000000000004
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x32135e550>)
